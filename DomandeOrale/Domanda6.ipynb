# %%
"""Domanda 6 (Approssimazione minimimi quadrati). Discutere l’approssimazione a m dati 
equispaziati ottenuti campionando la funzione f (x) = 1/1+25*x^2 nell’intervallo [−1, 1] 
usando polinomi di grado n ∈ {1, 2, 3, 5, 7}.
Si risolva il problema dei minimi quadrati sia mediante le equazioni normali che con SVD, 
calcolando l’errore di approssimazione in norma 2 per entrambi i metodi. Infine graficare le
approssimazioni polinomiali ottenute."""
import numpy as np
from scipy.linalg import cholesky
from numpy.linalg import svd, solve
import matplotlib.pyplot as plt
from numpy.linalg import norm

# %%
def f(x):
    return 1/(1+25*(x**2))

a, b = -1, 1
m = 10
m_plot = 100
n_values = [1, 2, 3, 5, 7]

x_observed = np.linspace(a, b, m)
y_observed = f(x_observed)

def create_matrix_A(x, n):
    A = np.zeros((len(x), n+1))
    for i in range(n+1):
        A[:, i] = x**i
    return A

for n in n_values:
    print(f'\n data n: {n}\n')
    A = create_matrix_A(x_observed, n)
    x_exact = np.ones((n+1, 1))
    b = np.dot(A, x_exact)
    print(f'Matrice A:\n{A}\n')
    print(f'x: \n{x_exact}\n')
    print(f'b: \n{b}\n')

    print(f'Metodo dei minimi quadrati con Cholesky per n={n}:\n')
    L = cholesky(np.dot(A.T, A), lower=True)
    x_chol = solve(L.T, solve(L, np.dot(A.T, b)))
    alpha_chol = solve(L, x_chol)
    error_chol = norm(np.dot(A, alpha_chol) - y_observed, 2)
    print(f'Soluzione alpha calcolata (Cholesky): \n{alpha_chol}')
    print(f'Errore approssimazione metodo Cholesky: {error_chol}\n')

    print(f'Metodo dei minimi quadrati con SVD per n={n}:\n')
    U, s, Vh = svd(A)
    alpha_svd = np.zeros(n+1)
    for i in range(n+1):
        ui = U[:, i]
        vi = Vh[i, :]
        alpha_svd = alpha_svd + (np.dot(ui, y_observed) * vi) / s[i]
    error_svd = norm(np.dot(A, alpha_svd) - y_observed, 2)
    print(f'Soluzione alpha con SVD: {alpha_svd}\n')
    print(f'Errore approssimazione metodo SVD: {error_svd}\n')

    x_plot = np.linspace(x_observed[0], x_observed[-1], m_plot)
    A_plot = np.zeros((m_plot, n+1))
    for i in range(n+1):
        A_plot[:, i] = x_plot**i 
    y_interpolation = A_plot @ alpha_svd 
    
    plt.plot(x_observed, y_observed, 'o') 
    plt.plot(x_plot, y_interpolation, 'r') 
    plt.xlabel('x')
    plt.ylabel('y')
    plt.title(f'Interpolazione polinomiale di grado {n}')
    plt.grid()
    plt.show()
# Out:
#  data n: 1
#
# Matrice A:
# [[ 1.         -1.        ]
#  [ 1.         -0.77777778]
#  [ 1.         -0.55555556]
#  [ 1.         -0.33333333]
#  [ 1.         -0.11111111]
#  [ 1.          0.11111111]
#  [ 1.          0.33333333]
#  [ 1.          0.55555556]
#  [ 1.          0.77777778]
#  [ 1.          1.        ]]
#
# x:
# [[1.]
#  [1.]]
#
# b:
# [[0.        ]
#  [0.22222222]
#  [0.44444444]
#  [0.66666667]
#  [0.88888889]
#  [1.11111111]
#  [1.33333333]
#  [1.55555556]
#  [1.77777778]
#  [2.        ]]
#
# Metodo dei minimi quadrati con Cholesky per n=1:
#
# Soluzione alpha calcolata (Cholesky):
# [[0.31622777]
#  [0.49543369]]
# Errore approssimazione metodo Cholesky: 3.357932734409408
#
# Metodo dei minimi quadrati con SVD per n=1:
#
# Soluzione alpha con SVD: [2.48814136e-01 8.25062842e-17]
#
# Errore approssimazione metodo SVD: 0.8519889898800778
#  data n: 2
#
# Matrice A:
# [[ 1.         -1.          1.        ]
#  [ 1.         -0.77777778  0.60493827]
#  [ 1.         -0.55555556  0.30864198]
#  [ 1.         -0.33333333  0.11111111]
#  [ 1.         -0.11111111  0.01234568]
#  [ 1.          0.11111111  0.01234568]
#  [ 1.          0.33333333  0.11111111]
#  [ 1.          0.55555556  0.30864198]
#  [ 1.          0.77777778  0.60493827]
#  [ 1.          1.          1.        ]]
#
# x:
# [[1.]
#  [1.]
#  [1.]]
#
# b:
# [[1.        ]
#  [0.82716049]
#  [0.75308642]
#  [0.77777778]
#  [0.90123457]
#  [1.12345679]
#  [1.44444444]
#  [1.86419753]
#  [2.38271605]
#  [3.        ]]
#
# Metodo dei minimi quadrati con Cholesky per n=2:
#
# Soluzione alpha calcolata (Cholesky):
# [[0.31622777]
#  [0.49543369]
#  [0.52223297]]
# Errore approssimazione metodo Cholesky: 4.963850505201406
#
# Metodo dei minimi quadrati con SVD per n=2:
#
# Soluzione alpha con SVD: [ 4.74479148e-01  1.26525191e-16 -5.53905029e-01]
#
# Errore approssimazione metodo SVD: 0.5751808755886042
#  data n: 3
#
# Matrice A:
# [[ 1.         -1.          1.         -1.        ]
#  [ 1.         -0.77777778  0.60493827 -0.47050754]
#  [ 1.         -0.55555556  0.30864198 -0.17146776]
#  [ 1.         -0.33333333  0.11111111 -0.03703704]
#  [ 1.         -0.11111111  0.01234568 -0.00137174]
#  [ 1.          0.11111111  0.01234568  0.00137174]
#  [ 1.          0.33333333  0.11111111  0.03703704]
#  [ 1.          0.55555556  0.30864198  0.17146776]
#  [ 1.          0.77777778  0.60493827  0.47050754]
#  [ 1.          1.          1.          1.        ]]
#
# x:
# [[1.]
#  [1.]
#  [1.]
#  [1.]]
#
# b:
# [[0.        ]
#  [0.35665295]
#  [0.58161866]
#  [0.74074074]
#  [0.89986283]
#  [1.12482853]
#  [1.48148148]
#  [2.03566529]
#  [2.85322359]
#  [4.        ]]
#
# Metodo dei minimi quadrati con Cholesky per n=3:
#
# Soluzione alpha calcolata (Cholesky):
# [[0.31622777]
#  [0.49543369]
#  [0.52223297]
#  [0.45342519]]
# Errore approssimazione metodo Cholesky: 6.4358710781678985
#
# Metodo dei minimi quadrati con SVD per n=3:
#
# Soluzione alpha con SVD: [ 4.74479148e-01 -1.83228478e-16 -5.53905029e-01  4.80982767e-16]
#
# Errore approssimazione metodo SVD: 0.5751808755886042
#  data n: 5
#
# Matrice A:
# [[ 1.00000000e+00 -1.00000000e+00  1.00000000e+00 -1.00000000e+00
#    1.00000000e+00 -1.00000000e+00]
#  [ 1.00000000e+00 -7.77777778e-01  6.04938272e-01 -4.70507545e-01
#    3.65950312e-01 -2.84628021e-01]
#  [ 1.00000000e+00 -5.55555556e-01  3.08641975e-01 -1.71467764e-01
#    9.52598689e-02 -5.29221494e-02]
#  [ 1.00000000e+00 -3.33333333e-01  1.11111111e-01 -3.70370370e-02
#    1.23456790e-02 -4.11522634e-03]
#  [ 1.00000000e+00 -1.11111111e-01  1.23456790e-02 -1.37174211e-03
#    1.52415790e-04 -1.69350878e-05]
#  [ 1.00000000e+00  1.11111111e-01  1.23456790e-02  1.37174211e-03
#    1.52415790e-04  1.69350878e-05]
#  [ 1.00000000e+00  3.33333333e-01  1.11111111e-01  3.70370370e-02
#    1.23456790e-02  4.11522634e-03]
#  [ 1.00000000e+00  5.55555556e-01  3.08641975e-01  1.71467764e-01
#    9.52598689e-02  5.29221494e-02]
#  [ 1.00000000e+00  7.77777778e-01  6.04938272e-01  4.70507545e-01
#    3.65950312e-01  2.84628021e-01]
#  [ 1.00000000e+00  1.00000000e+00  1.00000000e+00  1.00000000e+00
#    1.00000000e+00  1.00000000e+00]]
#
# x:
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]]
#
# b:
# [[0.        ]
#  [0.43797524]
#  [0.62395638]
#  [0.74897119]
#  [0.89999831]
#  [1.12499788]
#  [1.49794239]
#  [2.18384731]
#  [3.50380193]
#  [6.        ]]
#
# Metodo dei minimi quadrati con Cholesky per n=5:
#
# Soluzione alpha calcolata (Cholesky):
# [[0.31622777]
#  [0.49543369]
#  [0.52223297]
#  [0.45342519]
#  [0.33658092]
#  [0.21483446]]
# Errore approssimazione metodo Cholesky: 8.067002455164186
#
# Metodo dei minimi quadrati con SVD per n=5:
#
# Soluzione alpha con SVD: [ 6.42191979e-01  1.89909169e-16 -1.99646993e+00 -2.06753090e-15
#   1.42497265e+00  2.04186400e-15]
#
# Errore approssimazione metodo SVD: 0.36318383547544597
#  data n: 7
#
# Matrice A:
# [[ 1.00000000e+00 -1.00000000e+00  1.00000000e+00 -1.00000000e+00
#    1.00000000e+00 -1.00000000e+00  1.00000000e+00 -1.00000000e+00]
#  [ 1.00000000e+00 -7.77777778e-01  6.04938272e-01 -4.70507545e-01
#    3.65950312e-01 -2.84628021e-01  2.21377350e-01 -1.72182383e-01]
#  [ 1.00000000e+00 -5.55555556e-01  3.08641975e-01 -1.71467764e-01
#    9.52598689e-02 -5.29221494e-02  2.94011941e-02 -1.63339967e-02]
#  [ 1.00000000e+00 -3.33333333e-01  1.11111111e-01 -3.70370370e-02
#    1.23456790e-02 -4.11522634e-03  1.37174211e-03 -4.57247371e-04]
#  [ 1.00000000e+00 -1.11111111e-01  1.23456790e-02 -1.37174211e-03
#    1.52415790e-04 -1.69350878e-05  1.88167642e-06 -2.09075158e-07]
#  [ 1.00000000e+00  1.11111111e-01  1.23456790e-02  1.37174211e-03
#    1.52415790e-04  1.69350878e-05  1.88167642e-06  2.09075158e-07]
#  [ 1.00000000e+00  3.33333333e-01  1.11111111e-01  3.70370370e-02
#    1.23456790e-02  4.11522634e-03  1.37174211e-03  4.57247371e-04]
#  [ 1.00000000e+00  5.55555556e-01  3.08641975e-01  1.71467764e-01
#    9.52598689e-02  5.29221494e-02  2.94011941e-02  1.63339967e-02]
#  [ 1.00000000e+00  7.77777778e-01  6.04938272e-01  4.70507545e-01
#    3.65950312e-01  2.84628021e-01  2.21377350e-01  1.72182383e-01]
#  [ 1.00000000e+00  1.00000000e+00  1.00000000e+00  1.00000000e+00
#    1.00000000e+00  1.00000000e+00  1.00000000e+00  1.00000000e+00]]
#
# x:
# [[1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]
#  [1.]]
#
# b:
# [[0.        ]
#  [0.48717021]
#  [0.63702357]
#  [0.74988569]
#  [0.89999998]
#  [1.12499997]
#  [1.49977138]
#  [2.2295825 ]
#  [3.89736166]
#  [8.        ]]
#
# Metodo dei minimi quadrati con Cholesky per n=7:
#
# Soluzione alpha calcolata (Cholesky):
# [[0.31622777]
#  [0.49543369]
#  [0.52223297]
#  [0.45342519]
#  [0.33658092]
#  [0.21483446]
#  [0.11677484]
#  [0.05269379]]
# Errore approssimazione metodo Cholesky: 8.546761410390403
#
# Metodo dei minimi quadrati con SVD per n=7:
#
# Soluzione alpha con SVD: [ 7.67384095e-01  3.46095109e-14 -4.47552598e+00  3.43476041e-14
#   8.29218923e+00  1.62958892e-15 -4.54921187e+00  4.57327865e-14]
#
# Errore approssimazione metodo SVD: 0.1939183846601575
